# %%
import pandas as pd
from pathlib import Path

step_1_path = Path("../Data/crawl2_files/extracted_metrics_unified.parquet")
step_2_path = Path("../Data/crawl2_files/thesis_meta_all_metrics_except_grade_and_supervisor_LEFT.parquet")
step_3_path = Path("/Users/oliver/Desktop/MSc_Speciale/ThesisDataRepo/data/crawl2/BASE_DATA_BIG.parquet")

step_1 = pd.read_parquet(step_1_path)
print(f"Rows in step_1 DataFrame: {len(step_1)}")
print(f"Unique filenames in step_1 DataFrame: {step_1['filename'].nunique()}")
step_2 = pd.read_parquet(step_2_path)
print(f"Rows in step_2 DataFrame: {len(step_2)}")
print(f"Unique filenames in step_2 DataFrame: {step_2['filename'].nunique()}")
step_3 = pd.read_parquet(step_3_path)
print(f"Rows in step_3 DataFrame: {len(step_3)}")
print(f"Unique filenames in step_3 DataFrame: {step_3['filename'].nunique()}")
# Out:
# Rows in step_1 DataFrame: 9889
# Unique filenames in step_1 DataFrame: 9889
# Rows in step_2 DataFrame: 9889
# Unique filenames in step_2 DataFrame: 9889
# Rows in step_3 DataFrame: 9619
# Unique filenames in step_3 DataFrame: 9619

# %% [markdown]
# ### Step 1

# %%
df_1 = step_1.copy()
# new column "ID" by splitting "filename" at ".txt" and taking the first part
df_1["ID"] = df_1["filename"].str.split(".txt").str[0].astype(str)
# place ID column at the second index (after filename)
cols = df_1.columns.tolist()
cols.insert(1, cols.pop(cols.index("ID")))
df_1 = df_1[cols]
display(df_1.head())

len(df_1["ID"].unique())
# Out:
#          filename          ID  num_tot_pages  num_cont_pages  num_words_full  \
# 0  2692305267.txt  2692305267             50              45            9398
# 1  2439430818.txt  2439430818             81              77           12223
# 2  2712810173.txt  2712810173             54              39           14897
# 3  2712907369.txt  2712907369             63              50           16425
# 4  2385162063.txt  2385162063             75              58           17712
#
#    num_words_cont  num_figures  num_tables  num_references  total_sentences  \
# 0            7940         41.0         8.0            69.0            429.0
# 1           11648         64.0         6.0            29.0            582.0
# 2           11982         31.0        14.0            58.0            577.0
# 3           14009         24.0         8.0             NaN            701.0
# 4           14056         36.0         4.0            23.0            642.0
#
#    ...  lexical_diversity  flesch_kincaid_grade   handin_month  abstract_ts  \
# 0  ...              0.209                  11.9  February 2180         None
# 1  ...              0.155                   9.1    August 2018         None
# 2  ...              0.179                  12.3      June 2022         None
# 3  ...              0.161                  12.0      June 2022         None
# 4  ...              0.174                   9.4    August 2017         None
#
#    Author  num_authors Publication Year primary_member_id_s Title  \
# 0    None          NaN              NaN                None  None
# 1    None          NaN              NaN                None  None
# 2    None          NaN              NaN                None  None
# 3    None          NaN              NaN                None  None
# 4    None          NaN              NaN                None  None
#
#    Department_new
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
#
# [5 rows x 24 columns]
# 9889

# %% [markdown]
# ### Step 2

# %%
meta_path = Path("../Data/crawl2_files/meta_findit/meta_findit_all_merged.csv")
df_meta = pd.read_csv(meta_path,sep=";", low_memory=False)
df_meta["ID"] = df_meta["ID"].astype(str)
print(f"Rows in meta DataFrame: {len(df_meta)}")
print(f"Unique IDs in meta DataFrame: {df_meta['ID'].nunique()}")
# Out:
# Rows in meta DataFrame: 30961
# Unique IDs in meta DataFrame: 15414

# %%
df_union = pd.merge(df_1[["filename", "ID"]], df_meta[["ID"]], on="ID", how="inner", suffixes=("_metrics", "_meta"))
# Showing the dataframe in a simple way to check the merge result with only the IDs and filenames from both dataframes
display(df_union)

print(f"Rows in union DataFrame: {len(df_union)}")
print(f"Unique IDs in union DataFrame: {df_union['ID'].nunique()}")
# Out:
#              filename          ID
# 0      2692305267.txt  2692305267
# 1      2692305267.txt  2692305267
# 2      2439430818.txt  2439430818
# 3      2439430818.txt  2439430818
# 4      2712810173.txt  2712810173
# ...               ...         ...
# 19823  2692890879.txt  2692890879
# 19824  2692890879.txt  2692890879
# 19825  2737702132.txt  2737702132
# 19826  2737702132.txt  2737702132
# 19827  2737702132.txt  2737702132
#
# [19828 rows x 2 columns]
# Rows in union DataFrame: 19828
# Unique IDs in union DataFrame: 9618

# %%
df_2 = step_2.copy()
# new column "ID" by splitting "filename" at ".txt" and taking the first part
#df_2["ID"] = df_2["filename"].str.split(".txt").str[0]
# place ID column at the second index (after filename)
# cols = df_2.columns.tolist()
# cols.insert(1, cols.pop(cols.index("ID")))
# df_2 = df_2[cols]
display(df_2)

len(df_2["ID"].unique())
# Out:
#             filename  num_tot_pages  num_cont_pages  num_words_full  \
# 0     2692305267.txt             50              45            9398
# 1     2439430818.txt             81              77           12223
# 2     2712810173.txt             54              39           14897
# 3     2712907369.txt             63              50           16425
# 4     2385162063.txt             75              58           17712
# ...              ...            ...             ...             ...
# 9884  2451029150.txt             75              57           21279
# 9885  2497546697.txt             59              44           13323
# 9886  2692890879.txt             47              45           14097
# 9887  2728315454.txt             50              47           11707
# 9888  2737702132.txt             88              75           31006
#
#       num_words_cont  num_figures  num_tables  num_references  \
# 0               7940         41.0         8.0            69.0
# 1              11648         64.0         6.0            29.0
# 2              11982         31.0        14.0            58.0
# 3              14009         24.0         8.0             NaN
# 4              14056         36.0         4.0            23.0
# ...              ...          ...         ...             ...
# 9884           18777         54.0        10.0            62.0
# 9885           12190         29.0         7.0             NaN
# 9886           14071         38.0         0.0            14.0
# 9887           11568         25.0         2.0            28.0
# 9888           28025         47.0        17.0            46.0
#
#       total_sentences  total_words  ...  flesch_kincaid_grade   handin_month  \
# 0               429.0       8168.0  ...                  11.9  February 2180
# 1               582.0       9342.0  ...                   9.1    August 2018
# 2               577.0      10988.0  ...                  12.3      June 2022
# 3               701.0      14379.0  ...                  12.0      June 2022
# 4               642.0      11983.0  ...                   9.4    August 2017
# ...               ...          ...  ...                   ...            ...
# 9884            905.0      16533.0  ...                  11.2       May 2019
# 9885            596.0      12368.0  ...                  12.5  February 2020
# 9886            620.0      12793.0  ...                  11.1      July 2021
# 9887            603.0      11239.0  ...                  11.6  December 4292
# 9888           1518.0      27455.0  ...                  10.6      June 2024
#
#       abstract_ts                                           Author  \
# 0             NaN                                        Jiang, Qi
# 1             NaN  Venkata, Pawan Krishna Mohan Rao Sriperumbuduri
# 2             NaN                                   Tomulic, Petra
# 3             NaN                          Jørgensen, Lucas Rebien
# 4             NaN                      Montero, Mariana Montenegro
# ...           ...                                              ...
# 9884          NaN                                Moolman, Johannes
# 9885          NaN                        Muchena, Chenai Elizabeth
# 9886          NaN                                Thapa, Umesh Saru
# 9887          NaN                                              NaN
# 9888          NaN                     Rasmussen, Kasper Juul Hesse
#
#       num_authors Publication Year       primary_member_id_s  \
# 0             1.0           2021.0  61110d1ad9001d016215791c
# 1             1.0           2018.0  5ba4d1d3d9001d01b30b153d
# 2             1.0           2022.0  62dddf6ea0492e54e4cb319f
# 3             1.0           2022.0  62e5c84932d573a44628047a
# 4             1.0           2017.0  59b7bf685010df28b56065bc
# ...           ...              ...                       ...
# 9884          1.0           2019.0  5d3d8417d9001d32f558c327
# 9885          1.0           2020.0  5e60ec9fd9001d016338acd5
# 9886          1.0           2021.0  6120df23d9001d0478369047
# 9887          NaN              NaN                       NaN
# 9888          1.0           2024.0  669da344dd1c90e8f3f97411
#
#                                                   Title      Department_new  \
# 0     Growth of Lactococcus lactis and microbial met...            DTU Food
# 1     Design and Analysis of a 300 GHz Integrated Po...         DTU Electro
# 2     Bestemmelse af bionedbrydningskinetik for esse...         DTU Sustain
# 3     New analytical method for direct determination...     DTU Health Tech
# 4     Optimization of cyclic pitch control for a ver...            DTU Wind
# ...                                                 ...                 ...
# 9884  Operating a hybrid power plant in the Australi...            DTU Wind
# 9885  Secondary metabolites from Streptomyces iranen...  DTU Bioengineering
# 9886  Evaluation of Outdoor Electroluminescence Imag...         DTU Electro
# 9887                                                NaN                 NaN
# 9888  Analysis and hardware implementation of compre...         DTU Compute
#
#               ID
# 0     2692305267
# 1     2439430818
# 2     2712810173
# 3     2712907369
# 4     2385162063
# ...          ...
# 9884  2451029150
# 9885  2497546697
# 9886  2692890879
# 9887         NaN
# 9888  2737702132
#
# [9889 rows x 24 columns]
# 9619
